# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, LSTM, GRU
from sklearn.utils import resample
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load the dataset
df = pd.read_csv('combodataset.csv', header = None)

df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang', 
              'oldpeak', 'slope', 'target']

df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      40    1   2       140   289    0        0      172      0      0.0
# 1      49    0   3       160   180    0        0      156      0      1.0
# 2      37    1   2       130   283    0        1       98      0      0.0
# 3      48    0   4       138   214    0        0      108      1      1.5
# 4      54    1   3       150   195    0        0      122      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1185   45    1   1       110   264    0        0      132      0      1.2
# 1186   68    1   4       144   193    1        0      141      0      3.4
# 1187   57    1   4       130   131    0        0      115      1      1.2
# 1188   57    0   2       130   236    0        2      174      0      0.0
# 1189   38    1   3       138   175    0        0      173      0      0.0
#
#       slope  target
# 0         1       0
# 1         2       1
# 2         1       0
# 3         2       1
# 4         1       0
# ...     ...     ...
# 1185      2       1
# 1186      2       1
# 1187      2       1
# 1188      2       1
# 1189      1       0
#
# [1190 rows x 12 columns]

# %%
# Separate features and target variable
X = df.drop('target', axis=1)
y = df['target']

# %%
# 1. Load and preprocess the data
# Assuming you have your data in the X and y variables

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
input_shape = (X_train.shape[1], 1)
input_shape_cnn = (X_train.shape[1], 1)

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=11, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.25))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Dense(1, activation='sigmoid'))  # Output layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
# Train the individual models
cnn_model = build_cnn_model(input_shape)
cnn_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test),
             callbacks=[callback_early_stopping, callback_checkpoint])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 37ms/step - loss: 0.6085 - accuracy: 0.6499 - val_loss: 0.6263 - val_accuracy: 0.7563
# Epoch 2/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5188 - accuracy: 0.7633 - val_loss: 0.6078 - val_accuracy: 0.7542
# Epoch 3/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4940 - accuracy: 0.7829 - val_loss: 0.5928 - val_accuracy: 0.7143
# Epoch 4/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4701 - accuracy: 0.7941 - val_loss: 0.5989 - val_accuracy: 0.6282
# Epoch 5/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4523 - accuracy: 0.7997 - val_loss: 0.5838 - val_accuracy: 0.7458
# Epoch 6/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4392 - accuracy: 0.7983 - val_loss: 0.5705 - val_accuracy: 0.7710
# Epoch 7/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4585 - accuracy: 0.7969 - val_loss: 0.5660 - val_accuracy: 0.7017
# Epoch 8/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3956 - accuracy: 0.8249 - val_loss: 0.5452 - val_accuracy: 0.7542
# Epoch 9/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4274 - accuracy: 0.8025 - val_loss: 0.5379 - val_accuracy: 0.8109
# Epoch 10/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4133 - accuracy: 0.8221 - val_loss: 0.5403 - val_accuracy: 0.8130
# Epoch 11/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.4174 - accuracy: 0.8137 - val_loss: 0.5182 - val_accuracy: 0.8130
# Epoch 12/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4134 - accuracy: 0.8263 - val_loss: 0.5128 - val_accuracy: 0.8340
# Epoch 13/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.4052 - accuracy: 0.8123 - val_loss: 0.5004 - val_accuracy: 0.8550
# Epoch 14/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4039 - accuracy: 0.8347 - val_loss: 0.4989 - val_accuracy: 0.8382
# Epoch 15/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3896 - accuracy: 0.8333 - val_loss: 0.4823 - val_accuracy: 0.8298
# Epoch 16/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3811 - accuracy: 0.8151 - val_loss: 0.4511 - val_accuracy: 0.8466
# Epoch 17/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3538 - accuracy: 0.8487 - val_loss: 0.4505 - val_accuracy: 0.8676
# Epoch 18/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3775 - accuracy: 0.8431 - val_loss: 0.4736 - val_accuracy: 0.8487
# Epoch 19/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3497 - accuracy: 0.8445 - val_loss: 0.4461 - val_accuracy: 0.8550
# Epoch 20/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3576 - accuracy: 0.8459 - val_loss: 0.4242 - val_accuracy: 0.8655
# Epoch 21/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3369 - accuracy: 0.8501 - val_loss: 0.4116 - val_accuracy: 0.8676
# Epoch 22/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3553 - accuracy: 0.8571 - val_loss: 0.4287 - val_accuracy: 0.8445
# Epoch 23/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3377 - accuracy: 0.8599 - val_loss: 0.4375 - val_accuracy: 0.8508
# Epoch 24/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3455 - accuracy: 0.8585 - val_loss: 0.4001 - val_accuracy: 0.8592
# Epoch 25/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3322 - accuracy: 0.8613 - val_loss: 0.4138 - val_accuracy: 0.8529
# Epoch 26/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3319 - accuracy: 0.8585 - val_loss: 0.3975 - val_accuracy: 0.8634
# Epoch 27/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3343 - accuracy: 0.8571 - val_loss: 0.3856 - val_accuracy: 0.8571
# Epoch 28/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3076 - accuracy: 0.8683 - val_loss: 0.3756 - val_accuracy: 0.8613
# Epoch 29/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2988 - accuracy: 0.8557 - val_loss: 0.3665 - val_accuracy: 0.8634
# Epoch 30/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2957 - accuracy: 0.8838 - val_loss: 0.3825 - val_accuracy: 0.8655
# Epoch 31/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3050 - accuracy: 0.8768 - val_loss: 0.3703 - val_accuracy: 0.8592
# Epoch 32/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3106 - accuracy: 0.8739 - val_loss: 0.3603 - val_accuracy: 0.8592
# Epoch 33/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.2632 - accuracy: 0.8824 - val_loss: 0.3483 - val_accuracy: 0.8718
# Epoch 34/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2662 - accuracy: 0.8824 - val_loss: 0.3526 - val_accuracy: 0.8634
# Epoch 35/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2668 - accuracy: 0.8922 - val_loss: 0.3571 - val_accuracy: 0.8634
# Epoch 36/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2754 - accuracy: 0.8852 - val_loss: 0.3591 - val_accuracy: 0.8718
# Epoch 37/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2738 - accuracy: 0.8824 - val_loss: 0.3567 - val_accuracy: 0.8634
# Epoch 38/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2638 - accuracy: 0.8852 - val_loss: 0.3464 - val_accuracy: 0.8718
# Epoch 39/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.2676 - accuracy: 0.8908 - val_loss: 0.3425 - val_accuracy: 0.8676
# Epoch 40/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2372 - accuracy: 0.8978 - val_loss: 0.3502 - val_accuracy: 0.8761
# Epoch 41/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2408 - accuracy: 0.9062 - val_loss: 0.3481 - val_accuracy: 0.8676
# Epoch 42/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2354 - accuracy: 0.8992 - val_loss: 0.3524 - val_accuracy: 0.8718
# Epoch 43/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2375 - accuracy: 0.9048 - val_loss: 0.3485 - val_accuracy: 0.8697
# Epoch 44/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2393 - accuracy: 0.8922 - val_loss: 0.3425 - val_accuracy: 0.8782
# Epoch 45/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2043 - accuracy: 0.9174 - val_loss: 0.3523 - val_accuracy: 0.8782
# Epoch 46/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.2202 - accuracy: 0.9146 - val_loss: 0.3467 - val_accuracy: 0.8655
# Epoch 47/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.2317 - accuracy: 0.9034 - val_loss: 0.3685 - val_accuracy: 0.8634
# Epoch 48/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2301 - accuracy: 0.9062 - val_loss: 0.3532 - val_accuracy: 0.8676
# Epoch 49/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.2005 - accuracy: 0.9188 - val_loss: 0.3637 - val_accuracy: 0.8676

# %%
# 8. Evaluate the model
test_loss, test_accuracy = cnn_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3425 - accuracy: 0.8676
# Test Loss: 0.3425
# Test Accuracy: 0.8676

# %%
# Make predictions
y_pred = cnn_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 15/15 [==============================] - 0s 2ms/step
# Confusion Matrix:
# [[182  36]
#  [ 27 231]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       218
#            1       0.87      0.90      0.88       258
#
#     accuracy                           0.87       476
#    macro avg       0.87      0.87      0.87       476
# weighted avg       0.87      0.87      0.87       476

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(11, return_sequences=True, input_shape=input_shape))
    model.add(LSTM(32, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(32))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
lstm_model = build_lstm_model(input_shape)
lstm_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test),
              callbacks=[callback_early_stopping, callback_checkpoint])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 13s 203ms/step - loss: 0.6445 - accuracy: 0.6527 - val_loss: 0.6749 - val_accuracy: 0.5294
# Epoch 2/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.5968 - accuracy: 0.7003 - val_loss: 0.6642 - val_accuracy: 0.5567
# Epoch 3/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.5723 - accuracy: 0.7031 - val_loss: 0.6487 - val_accuracy: 0.6218
# Epoch 4/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.5866 - accuracy: 0.7115 - val_loss: 0.6567 - val_accuracy: 0.6471
# Epoch 5/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.5529 - accuracy: 0.7325 - val_loss: 0.6584 - val_accuracy: 0.6239
# Epoch 6/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.5477 - accuracy: 0.7339 - val_loss: 0.6548 - val_accuracy: 0.6155
# Epoch 7/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.5455 - accuracy: 0.7353 - val_loss: 0.6517 - val_accuracy: 0.6345
# Epoch 8/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.5128 - accuracy: 0.7563 - val_loss: 0.6399 - val_accuracy: 0.6828
# Epoch 9/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.5128 - accuracy: 0.7437 - val_loss: 0.6390 - val_accuracy: 0.6576
# Epoch 10/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.4828 - accuracy: 0.7535 - val_loss: 0.6319 - val_accuracy: 0.7437
# Epoch 11/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.4576 - accuracy: 0.7829 - val_loss: 0.6066 - val_accuracy: 0.7479
# Epoch 12/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.4297 - accuracy: 0.8165 - val_loss: 0.6010 - val_accuracy: 0.7185
# Epoch 13/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.4231 - accuracy: 0.7955 - val_loss: 0.6290 - val_accuracy: 0.5987
# Epoch 14/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.4127 - accuracy: 0.8053 - val_loss: 0.5924 - val_accuracy: 0.7332
# Epoch 15/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.4149 - accuracy: 0.8053 - val_loss: 0.5806 - val_accuracy: 0.8445
# Epoch 16/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3947 - accuracy: 0.8277 - val_loss: 0.5669 - val_accuracy: 0.8172
# Epoch 17/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.3818 - accuracy: 0.8417 - val_loss: 0.5728 - val_accuracy: 0.7731
# Epoch 18/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3771 - accuracy: 0.8333 - val_loss: 0.5571 - val_accuracy: 0.8067
# Epoch 19/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.3771 - accuracy: 0.8403 - val_loss: 0.5552 - val_accuracy: 0.8361
# Epoch 20/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.3794 - accuracy: 0.8277 - val_loss: 0.5425 - val_accuracy: 0.8340
# Epoch 21/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.3738 - accuracy: 0.8375 - val_loss: 0.5362 - val_accuracy: 0.7920
# Epoch 22/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3614 - accuracy: 0.8473 - val_loss: 0.5204 - val_accuracy: 0.8256
# Epoch 23/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3632 - accuracy: 0.8487 - val_loss: 0.5088 - val_accuracy: 0.8256
# Epoch 24/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3602 - accuracy: 0.8515 - val_loss: 0.4866 - val_accuracy: 0.8109
# Epoch 25/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3555 - accuracy: 0.8417 - val_loss: 0.4814 - val_accuracy: 0.8340
# Epoch 26/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.3463 - accuracy: 0.8445 - val_loss: 0.4944 - val_accuracy: 0.8445
# Epoch 27/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.3313 - accuracy: 0.8585 - val_loss: 0.4662 - val_accuracy: 0.8403
# Epoch 28/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.3477 - accuracy: 0.8473 - val_loss: 0.4696 - val_accuracy: 0.8550
# Epoch 29/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.3505 - accuracy: 0.8431 - val_loss: 0.4839 - val_accuracy: 0.8025
# Epoch 30/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3337 - accuracy: 0.8599 - val_loss: 0.4417 - val_accuracy: 0.8592
# Epoch 31/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.3201 - accuracy: 0.8627 - val_loss: 0.4376 - val_accuracy: 0.8382
# Epoch 32/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3336 - accuracy: 0.8543 - val_loss: 0.4153 - val_accuracy: 0.8613
# Epoch 33/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.3295 - accuracy: 0.8585 - val_loss: 0.4232 - val_accuracy: 0.8655
# Epoch 34/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.3017 - accuracy: 0.8711 - val_loss: 0.4058 - val_accuracy: 0.8550
# Epoch 35/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.3047 - accuracy: 0.8641 - val_loss: 0.4225 - val_accuracy: 0.8235
# Epoch 36/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.2942 - accuracy: 0.8754 - val_loss: 0.3884 - val_accuracy: 0.8403
# Epoch 37/100
# 15/15 [==============================] - 1s 50ms/step - loss: 0.2853 - accuracy: 0.8768 - val_loss: 0.3528 - val_accuracy: 0.8845
# Epoch 38/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.3046 - accuracy: 0.8711 - val_loss: 0.3700 - val_accuracy: 0.8508
# Epoch 39/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.3089 - accuracy: 0.8683 - val_loss: 0.3818 - val_accuracy: 0.8592
# Epoch 40/100
# 15/15 [==============================] - 1s 38ms/step - loss: 0.2818 - accuracy: 0.8810 - val_loss: 0.3677 - val_accuracy: 0.8697
# Epoch 41/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.2833 - accuracy: 0.8725 - val_loss: 0.3580 - val_accuracy: 0.8634
# Epoch 42/100
# 15/15 [==============================] - 1s 49ms/step - loss: 0.2641 - accuracy: 0.8866 - val_loss: 0.3274 - val_accuracy: 0.8824
# Epoch 43/100
# 15/15 [==============================] - 1s 38ms/step - loss: 0.2492 - accuracy: 0.8964 - val_loss: 0.3597 - val_accuracy: 0.8718
# Epoch 44/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.2420 - accuracy: 0.9006 - val_loss: 0.3363 - val_accuracy: 0.8845
# Epoch 45/100
# 15/15 [==============================] - 1s 38ms/step - loss: 0.2480 - accuracy: 0.9076 - val_loss: 0.3493 - val_accuracy: 0.8739
# Epoch 46/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.2440 - accuracy: 0.8992 - val_loss: 0.3524 - val_accuracy: 0.8718
# Epoch 47/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.2537 - accuracy: 0.8992 - val_loss: 0.3636 - val_accuracy: 0.8655
# Epoch 48/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.2460 - accuracy: 0.9006 - val_loss: 0.3649 - val_accuracy: 0.8634
# Epoch 49/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.2251 - accuracy: 0.9132 - val_loss: 0.3813 - val_accuracy: 0.8445
# Epoch 50/100
# 15/15 [==============================] - 1s 38ms/step - loss: 0.2283 - accuracy: 0.9090 - val_loss: 0.3736 - val_accuracy: 0.8824
# Epoch 51/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.2337 - accuracy: 0.9034 - val_loss: 0.3503 - val_accuracy: 0.8824
# Epoch 52/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.2240 - accuracy: 0.9104 - val_loss: 0.3736 - val_accuracy: 0.8697

# %%
# 8. Evaluate the model
test_loss, test_accuracy = lstm_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3274 - accuracy: 0.8824
# Test Loss: 0.3274
# Test Accuracy: 0.8824

# %%
# Make predictions
y_pred = lstm_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 15/15 [==============================] - 3s 10ms/step
# Confusion Matrix:
# [[187  31]
#  [ 25 233]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       218
#            1       0.88      0.90      0.89       258
#
#     accuracy                           0.88       476
#    macro avg       0.88      0.88      0.88       476
# weighted avg       0.88      0.88      0.88       476

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(11, return_sequences=True, input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(GRU(32, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(GRU(64, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(GRU(128, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(GRU(128))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
gru_model = build_gru_model(input_shape)
gru_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test),
             callbacks=[callback_early_stopping, callback_checkpoint])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 19s 284ms/step - loss: 0.6109 - accuracy: 0.6765 - val_loss: 0.6882 - val_accuracy: 0.5882
# Epoch 2/100
# 15/15 [==============================] - 1s 74ms/step - loss: 0.5187 - accuracy: 0.7605 - val_loss: 0.6883 - val_accuracy: 0.6975
# Epoch 3/100
# 15/15 [==============================] - 1s 89ms/step - loss: 0.4730 - accuracy: 0.7675 - val_loss: 0.6874 - val_accuracy: 0.5588
# Epoch 4/100
# 15/15 [==============================] - 1s 93ms/step - loss: 0.4571 - accuracy: 0.7927 - val_loss: 0.6844 - val_accuracy: 0.6071
# Epoch 5/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.4685 - accuracy: 0.7801 - val_loss: 0.6818 - val_accuracy: 0.5105
# Epoch 6/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.4418 - accuracy: 0.8067 - val_loss: 0.6774 - val_accuracy: 0.5126
# Epoch 7/100
# 15/15 [==============================] - 1s 73ms/step - loss: 0.4143 - accuracy: 0.8165 - val_loss: 0.6807 - val_accuracy: 0.4643
# Epoch 8/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.4175 - accuracy: 0.8221 - val_loss: 0.6712 - val_accuracy: 0.4685
# Epoch 9/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.4281 - accuracy: 0.8123 - val_loss: 0.6531 - val_accuracy: 0.6282
# Epoch 10/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.4114 - accuracy: 0.8109 - val_loss: 0.6256 - val_accuracy: 0.7374
# Epoch 11/100
# 15/15 [==============================] - 1s 73ms/step - loss: 0.4079 - accuracy: 0.8221 - val_loss: 0.6263 - val_accuracy: 0.7143
# Epoch 12/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.4365 - accuracy: 0.8123 - val_loss: 0.6198 - val_accuracy: 0.6618
# Epoch 13/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.3906 - accuracy: 0.8291 - val_loss: 0.5687 - val_accuracy: 0.7290
# Epoch 14/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.3965 - accuracy: 0.8109 - val_loss: 0.5524 - val_accuracy: 0.7290
# Epoch 15/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.3762 - accuracy: 0.8319 - val_loss: 0.5382 - val_accuracy: 0.7500
# Epoch 16/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.3690 - accuracy: 0.8361 - val_loss: 0.4998 - val_accuracy: 0.7878
# Epoch 17/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.3756 - accuracy: 0.8319 - val_loss: 0.4579 - val_accuracy: 0.7983
# Epoch 18/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.3725 - accuracy: 0.8375 - val_loss: 0.4390 - val_accuracy: 0.8193
# Epoch 19/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.3804 - accuracy: 0.8207 - val_loss: 0.4775 - val_accuracy: 0.7857
# Epoch 20/100
# 15/15 [==============================] - 1s 71ms/step - loss: 0.3453 - accuracy: 0.8361 - val_loss: 0.4599 - val_accuracy: 0.7941
# Epoch 21/100
# 15/15 [==============================] - 1s 71ms/step - loss: 0.3616 - accuracy: 0.8473 - val_loss: 0.4526 - val_accuracy: 0.7920
# Epoch 22/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.3441 - accuracy: 0.8557 - val_loss: 0.4492 - val_accuracy: 0.7794
# Epoch 23/100
# 15/15 [==============================] - 1s 86ms/step - loss: 0.3536 - accuracy: 0.8417 - val_loss: 0.4006 - val_accuracy: 0.8130
# Epoch 24/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.3594 - accuracy: 0.8445 - val_loss: 0.4063 - val_accuracy: 0.8298
# Epoch 25/100
# 15/15 [==============================] - 1s 83ms/step - loss: 0.3417 - accuracy: 0.8543 - val_loss: 0.3930 - val_accuracy: 0.8214
# Epoch 26/100
# 15/15 [==============================] - 1s 73ms/step - loss: 0.3500 - accuracy: 0.8473 - val_loss: 0.4201 - val_accuracy: 0.8067
# Epoch 27/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.3255 - accuracy: 0.8557 - val_loss: 0.3845 - val_accuracy: 0.8319
# Epoch 28/100
# 15/15 [==============================] - 1s 83ms/step - loss: 0.3268 - accuracy: 0.8529 - val_loss: 0.3562 - val_accuracy: 0.8571
# Epoch 29/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.3236 - accuracy: 0.8571 - val_loss: 0.3505 - val_accuracy: 0.8529
# Epoch 30/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.3029 - accuracy: 0.8739 - val_loss: 0.3381 - val_accuracy: 0.8655
# Epoch 31/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.3058 - accuracy: 0.8641 - val_loss: 0.3711 - val_accuracy: 0.8634
# Epoch 32/100
# 15/15 [==============================] - 1s 73ms/step - loss: 0.3365 - accuracy: 0.8445 - val_loss: 0.3543 - val_accuracy: 0.8571
# Epoch 33/100
# 15/15 [==============================] - 1s 84ms/step - loss: 0.3063 - accuracy: 0.8810 - val_loss: 0.3321 - val_accuracy: 0.8824
# Epoch 34/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.2965 - accuracy: 0.8768 - val_loss: 0.3717 - val_accuracy: 0.8718
# Epoch 35/100
# 15/15 [==============================] - 1s 73ms/step - loss: 0.3234 - accuracy: 0.8655 - val_loss: 0.3443 - val_accuracy: 0.8782
# Epoch 36/100
# 15/15 [==============================] - 1s 74ms/step - loss: 0.2970 - accuracy: 0.8824 - val_loss: 0.3470 - val_accuracy: 0.8739
# Epoch 37/100
# 15/15 [==============================] - 1s 85ms/step - loss: 0.2953 - accuracy: 0.8711 - val_loss: 0.3260 - val_accuracy: 0.9034
# Epoch 38/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.3015 - accuracy: 0.8768 - val_loss: 0.3659 - val_accuracy: 0.8697
# Epoch 39/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.2938 - accuracy: 0.8641 - val_loss: 0.3464 - val_accuracy: 0.8761
# Epoch 40/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.2550 - accuracy: 0.8992 - val_loss: 0.4059 - val_accuracy: 0.8487
# Epoch 41/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.2797 - accuracy: 0.8978 - val_loss: 0.3382 - val_accuracy: 0.8718
# Epoch 42/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.2453 - accuracy: 0.9048 - val_loss: 0.3380 - val_accuracy: 0.8824
# Epoch 43/100
# 15/15 [==============================] - 1s 73ms/step - loss: 0.2633 - accuracy: 0.8880 - val_loss: 0.3676 - val_accuracy: 0.8718
# Epoch 44/100
# 15/15 [==============================] - 1s 73ms/step - loss: 0.2572 - accuracy: 0.8964 - val_loss: 0.3446 - val_accuracy: 0.8929
# Epoch 45/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.2604 - accuracy: 0.9006 - val_loss: 0.3437 - val_accuracy: 0.8866
# Epoch 46/100
# 15/15 [==============================] - 1s 72ms/step - loss: 0.2666 - accuracy: 0.8810 - val_loss: 0.3722 - val_accuracy: 0.8676
# Epoch 47/100
# 15/15 [==============================] - 1s 74ms/step - loss: 0.2488 - accuracy: 0.9062 - val_loss: 0.3763 - val_accuracy: 0.8571

# %%
# 8. Evaluate the model
test_loss, test_accuracy = gru_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 15/15 [==============================] - 0s 17ms/step - loss: 0.3260 - accuracy: 0.9034
# Test Loss: 0.3260
# Test Accuracy: 0.9034

# %%
# Make predictions
y_pred = gru_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 15/15 [==============================] - 3s 16ms/step
# Confusion Matrix:
# [[191  27]
#  [ 19 239]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89       218
#            1       0.90      0.93      0.91       258
#
#     accuracy                           0.90       476
#    macro avg       0.90      0.90      0.90       476
# weighted avg       0.90      0.90      0.90       476

# %%
# Make predictions using individual models
cnn_predictions = (cnn_model.predict(X_test) > 0.5).astype("int32")
lstm_predictions = (lstm_model.predict(X_test) > 0.5).astype("int32")
gru_predictions = (gru_model.predict(X_test) > 0.5).astype("int32")
# Out:
# 15/15 [==============================] - 0s 3ms/step
# 15/15 [==============================] - 0s 10ms/step
# 15/15 [==============================] - 0s 15ms/step

# %%
# Combine predictions using a majority voting ensemble
ensemble_predictions = np.mean([cnn_predictions, lstm_predictions, gru_predictions], axis=0) >= 0.5
ensemble_predictions = ensemble_predictions.astype("int32")

# %%
# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, ensemble_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.9055

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, ensemble_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, ensemble_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, ensemble_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Confusion Matrix:
# [[193  25]
#  [ 20 238]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       218
#            1       0.90      0.92      0.91       258
#
#     accuracy                           0.91       476
#    macro avg       0.91      0.90      0.90       476
# weighted avg       0.91      0.91      0.91       476
#
# Ensemble Accuracy: 0.9055

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.utils import resample
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.model_selection import cross_val_score

# %%
# List of base models

lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

svm_l_model = SVC(kernel="linear")
svm_l_model.fit(X_train, y_train)

svm_p_model = SVC(kernel="poly")
svm_p_model.fit(X_train, y_train)

svm_r_model = SVC(kernel="rbf")
svm_r_model.fit(X_train, y_train)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)


knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)

gb_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_model.fit(X_train, y_train)

ab_model = AdaBoostClassifier(n_estimators=100, random_state=42)
ab_model.fit(X_train, y_train)

xgb_model = XGBClassifier(n_estimators=100, random_state=42)
xgb_model.fit(X_train, y_train)

gpc_model = GaussianProcessClassifier(random_state=42)
gpc_model.fit(X_train, y_train)
# Out:
# GaussianProcessClassifier(random_state=42)

# %%
lr_predictions = lr_model.predict(X_test)
svm_l_predictions = svm_l_model.predict(X_test)
svm_p_predictions = svm_p_model.predict(X_test)
svm_r_predictions = svm_r_model.predict(X_test)
rf_predictions = rf_model.predict(X_test)
knn_predictions = knn_model.predict(X_test)
gb_predictions = gb_model.predict(X_test)
ab_predictions = ab_model.predict(X_test)
xgb_predictions = xgb_model.predict(X_test)
gpc_predictions = gpc_model.predict(X_test)

# %%
# Combine predictions using ensemble (Voting Classifier)
ensemble_predictions = np.column_stack((cnn_predictions, lstm_predictions, gru_predictions, lr_predictions, 
                                        svm_l_predictions, svm_p_predictions, svm_r_predictions, 
                                        rf_predictions, knn_predictions, gb_predictions, 
                                        ab_predictions, xgb_predictions, gpc_predictions))

# %%
# Perform majority voting to get the final prediction
final_predictions = np.mean(ensemble_predictions, axis=1) >= 0.5
final_predictions = final_predictions.astype("int32")

# %%
# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.9181

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, final_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, final_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Confusion Matrix:
# [[193  25]
#  [ 14 244]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       218
#            1       0.91      0.95      0.93       258
#
#     accuracy                           0.92       476
#    macro avg       0.92      0.92      0.92       476
# weighted avg       0.92      0.92      0.92       476
#
# Ensemble Accuracy: 0.9181

# %%
# Combine predictions using ensemble (Voting Classifier)
ensemble_predictions = np.column_stack((cnn_predictions, lstm_predictions, gru_predictions, svm_r_predictions, 
                                        rf_predictions, knn_predictions, gb_predictions, 
                                        xgb_predictions, gpc_predictions))

# %%
# Perform majority voting to get the final prediction
final_predictions = np.mean(ensemble_predictions, axis=1) >= 0.5
final_predictions = final_predictions.astype("int32")

# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, final_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, final_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.9223
# Confusion Matrix:
# [[195  23]
#  [ 14 244]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       218
#            1       0.91      0.95      0.93       258
#
#     accuracy                           0.92       476
#    macro avg       0.92      0.92      0.92       476
# weighted avg       0.92      0.92      0.92       476
#
# Ensemble Accuracy: 0.9223
