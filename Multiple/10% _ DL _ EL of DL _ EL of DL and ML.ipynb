# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, LSTM, GRU
from sklearn.utils import resample
from sklearn.ensemble import VotingClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Load the dataset
df = pd.read_csv('combodataset.csv', header = None)

df.columns = ['age', 'sex', 'cp', 'trestbps', 'chol',
              'fbs', 'restecg', 'thalach', 'exang', 
              'oldpeak', 'slope', 'target']

df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      40    1   2       140   289    0        0      172      0      0.0
# 1      49    0   3       160   180    0        0      156      0      1.0
# 2      37    1   2       130   283    0        1       98      0      0.0
# 3      48    0   4       138   214    0        0      108      1      1.5
# 4      54    1   3       150   195    0        0      122      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1185   45    1   1       110   264    0        0      132      0      1.2
# 1186   68    1   4       144   193    1        0      141      0      3.4
# 1187   57    1   4       130   131    0        0      115      1      1.2
# 1188   57    0   2       130   236    0        2      174      0      0.0
# 1189   38    1   3       138   175    0        0      173      0      0.0
#
#       slope  target
# 0         1       0
# 1         2       1
# 2         1       0
# 3         2       1
# 4         1       0
# ...     ...     ...
# 1185      2       1
# 1186      2       1
# 1187      2       1
# 1188      2       1
# 1189      1       0
#
# [1190 rows x 12 columns]

# %%
# Separate features and target variable
X = df.drop('target', axis=1)
y = df['target']

# %%
# 1. Load and preprocess the data
# Assuming you have your data in the X and y variables

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
input_shape = (X_train.shape[1], 1)
input_shape_cnn = (X_train.shape[1], 1)

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_cnn_model(input_shape):
    model = Sequential()
    model.add(Conv1D(filters=11, kernel_size=3, activation='relu', input_shape=input_shape))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.25))
    model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Dense(1, activation='sigmoid'))  # Output layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
# Train the individual models
cnn_model = build_cnn_model(input_shape)
cnn_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test),
             callbacks=[callback_early_stopping, callback_checkpoint])
# Out:
# Epoch 1/100
# 22/22 [==============================] - 2s 22ms/step - loss: 0.5931 - accuracy: 0.7152 - val_loss: 0.5353 - val_accuracy: 0.6218
# Epoch 2/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.5072 - accuracy: 0.7638 - val_loss: 0.4870 - val_accuracy: 0.6639
# Epoch 3/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4392 - accuracy: 0.8077 - val_loss: 0.4351 - val_accuracy: 0.7731
# Epoch 4/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4302 - accuracy: 0.8179 - val_loss: 0.4240 - val_accuracy: 0.7731
# Epoch 5/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.4155 - accuracy: 0.8226 - val_loss: 0.3772 - val_accuracy: 0.8739
# Epoch 6/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.4133 - accuracy: 0.8151 - val_loss: 0.3898 - val_accuracy: 0.8487
# Epoch 7/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3900 - accuracy: 0.8347 - val_loss: 0.3541 - val_accuracy: 0.8487
# Epoch 8/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.4003 - accuracy: 0.8282 - val_loss: 0.3778 - val_accuracy: 0.8655
# Epoch 9/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3917 - accuracy: 0.8422 - val_loss: 0.3684 - val_accuracy: 0.8655
# Epoch 10/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3642 - accuracy: 0.8394 - val_loss: 0.3526 - val_accuracy: 0.8739
# Epoch 11/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3702 - accuracy: 0.8487 - val_loss: 0.3936 - val_accuracy: 0.8655
# Epoch 12/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3637 - accuracy: 0.8543 - val_loss: 0.3658 - val_accuracy: 0.8824
# Epoch 13/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3464 - accuracy: 0.8609 - val_loss: 0.3552 - val_accuracy: 0.8739
# Epoch 14/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3475 - accuracy: 0.8562 - val_loss: 0.3773 - val_accuracy: 0.8824
# Epoch 15/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3305 - accuracy: 0.8581 - val_loss: 0.3637 - val_accuracy: 0.8739
# Epoch 16/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3282 - accuracy: 0.8646 - val_loss: 0.3695 - val_accuracy: 0.8824
# Epoch 17/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3160 - accuracy: 0.8618 - val_loss: 0.3648 - val_accuracy: 0.8739
# Epoch 18/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3199 - accuracy: 0.8665 - val_loss: 0.3441 - val_accuracy: 0.8824
# Epoch 19/100
# 22/22 [==============================] - 0s 10ms/step - loss: 0.3247 - accuracy: 0.8702 - val_loss: 0.3312 - val_accuracy: 0.8992
# Epoch 20/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.3297 - accuracy: 0.8609 - val_loss: 0.3340 - val_accuracy: 0.8739
# Epoch 21/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3109 - accuracy: 0.8758 - val_loss: 0.3236 - val_accuracy: 0.8908
# Epoch 22/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.3106 - accuracy: 0.8758 - val_loss: 0.3386 - val_accuracy: 0.8824
# Epoch 23/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2895 - accuracy: 0.8786 - val_loss: 0.3216 - val_accuracy: 0.8992
# Epoch 24/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2830 - accuracy: 0.8786 - val_loss: 0.3396 - val_accuracy: 0.8571
# Epoch 25/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2734 - accuracy: 0.8870 - val_loss: 0.3238 - val_accuracy: 0.8908
# Epoch 26/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2797 - accuracy: 0.8777 - val_loss: 0.3240 - val_accuracy: 0.8908
# Epoch 27/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2777 - accuracy: 0.8730 - val_loss: 0.3297 - val_accuracy: 0.8739
# Epoch 28/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2721 - accuracy: 0.8898 - val_loss: 0.3364 - val_accuracy: 0.8824
# Epoch 29/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2619 - accuracy: 0.8926 - val_loss: 0.3299 - val_accuracy: 0.8824
# Epoch 30/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2481 - accuracy: 0.9010 - val_loss: 0.3480 - val_accuracy: 0.9076
# Epoch 31/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2430 - accuracy: 0.9094 - val_loss: 0.3309 - val_accuracy: 0.8908
# Epoch 32/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2416 - accuracy: 0.8964 - val_loss: 0.3215 - val_accuracy: 0.8992
# Epoch 33/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2403 - accuracy: 0.8973 - val_loss: 0.3233 - val_accuracy: 0.8992
# Epoch 34/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2320 - accuracy: 0.8973 - val_loss: 0.3907 - val_accuracy: 0.8739
# Epoch 35/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2247 - accuracy: 0.9048 - val_loss: 0.3493 - val_accuracy: 0.9076
# Epoch 36/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2301 - accuracy: 0.9122 - val_loss: 0.4006 - val_accuracy: 0.8824
# Epoch 37/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2453 - accuracy: 0.9057 - val_loss: 0.3415 - val_accuracy: 0.8824
# Epoch 38/100
# 22/22 [==============================] - 0s 9ms/step - loss: 0.2076 - accuracy: 0.9122 - val_loss: 0.3704 - val_accuracy: 0.8824
# Epoch 39/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2131 - accuracy: 0.9057 - val_loss: 0.4097 - val_accuracy: 0.8908
# Epoch 40/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.2010 - accuracy: 0.9178 - val_loss: 0.3277 - val_accuracy: 0.8908
# Epoch 41/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1971 - accuracy: 0.9206 - val_loss: 0.3528 - val_accuracy: 0.8739
# Epoch 42/100
# 22/22 [==============================] - 0s 8ms/step - loss: 0.1821 - accuracy: 0.9318 - val_loss: 0.3552 - val_accuracy: 0.8655

# %%
# 8. Evaluate the model
test_loss, test_accuracy = cnn_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3215 - accuracy: 0.8992
# Test Loss: 0.3215
# Test Accuracy: 0.8992

# %%
# Make predictions
y_pred = cnn_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# Confusion Matrix:
# [[44  3]
#  [ 9 63]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88        47
#            1       0.95      0.88      0.91        72
#
#     accuracy                           0.90       119
#    macro avg       0.89      0.91      0.90       119
# weighted avg       0.91      0.90      0.90       119

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(11, return_sequences=True, input_shape=input_shape))
    model.add(LSTM(32, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(32))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
lstm_model = build_lstm_model(input_shape)
lstm_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test),
              callbacks=[callback_early_stopping, callback_checkpoint])
# Out:
# Epoch 1/100
# 22/22 [==============================] - 15s 148ms/step - loss: 0.6156 - accuracy: 0.6965 - val_loss: 0.6442 - val_accuracy: 0.6387
# Epoch 2/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.5672 - accuracy: 0.7152 - val_loss: 0.6590 - val_accuracy: 0.6050
# Epoch 3/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.5613 - accuracy: 0.7068 - val_loss: 0.6562 - val_accuracy: 0.6050
# Epoch 4/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.5580 - accuracy: 0.7274 - val_loss: 0.6570 - val_accuracy: 0.6050
# Epoch 5/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.5427 - accuracy: 0.7395 - val_loss: 0.6472 - val_accuracy: 0.6050
# Epoch 6/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.5455 - accuracy: 0.7134 - val_loss: 0.6429 - val_accuracy: 0.6303
# Epoch 7/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.5336 - accuracy: 0.7376 - val_loss: 0.6360 - val_accuracy: 0.6134
# Epoch 8/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.5129 - accuracy: 0.7498 - val_loss: 0.6472 - val_accuracy: 0.6050
# Epoch 9/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.4922 - accuracy: 0.7703 - val_loss: 0.6390 - val_accuracy: 0.6050
# Epoch 10/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.4581 - accuracy: 0.7852 - val_loss: 0.5989 - val_accuracy: 0.6134
# Epoch 11/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.4275 - accuracy: 0.8030 - val_loss: 0.5963 - val_accuracy: 0.6134
# Epoch 12/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.4048 - accuracy: 0.8133 - val_loss: 0.5768 - val_accuracy: 0.6807
# Epoch 13/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.3887 - accuracy: 0.8301 - val_loss: 0.5854 - val_accuracy: 0.7395
# Epoch 14/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.3865 - accuracy: 0.8347 - val_loss: 0.5482 - val_accuracy: 0.7815
# Epoch 15/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.3942 - accuracy: 0.8254 - val_loss: 0.5571 - val_accuracy: 0.7647
# Epoch 16/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.3832 - accuracy: 0.8319 - val_loss: 0.4791 - val_accuracy: 0.8403
# Epoch 17/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.3683 - accuracy: 0.8366 - val_loss: 0.4639 - val_accuracy: 0.9076
# Epoch 18/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.3717 - accuracy: 0.8459 - val_loss: 0.4641 - val_accuracy: 0.8235
# Epoch 19/100
# 22/22 [==============================] - 1s 33ms/step - loss: 0.3693 - accuracy: 0.8366 - val_loss: 0.4755 - val_accuracy: 0.7395
# Epoch 20/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.3489 - accuracy: 0.8487 - val_loss: 0.4381 - val_accuracy: 0.7899
# Epoch 21/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.3506 - accuracy: 0.8441 - val_loss: 0.4357 - val_accuracy: 0.8319
# Epoch 22/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.3655 - accuracy: 0.8422 - val_loss: 0.4309 - val_accuracy: 0.8403
# Epoch 23/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.3488 - accuracy: 0.8543 - val_loss: 0.3551 - val_accuracy: 0.9244
# Epoch 24/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.3371 - accuracy: 0.8562 - val_loss: 0.3363 - val_accuracy: 0.8992
# Epoch 25/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.3340 - accuracy: 0.8525 - val_loss: 0.3253 - val_accuracy: 0.8739
# Epoch 26/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.3390 - accuracy: 0.8506 - val_loss: 0.3337 - val_accuracy: 0.9244
# Epoch 27/100
# 22/22 [==============================] - 1s 36ms/step - loss: 0.3210 - accuracy: 0.8599 - val_loss: 0.2445 - val_accuracy: 0.9412
# Epoch 28/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.3270 - accuracy: 0.8665 - val_loss: 0.2776 - val_accuracy: 0.9412
# Epoch 29/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.3146 - accuracy: 0.8674 - val_loss: 0.2809 - val_accuracy: 0.9328
# Epoch 30/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.3209 - accuracy: 0.8637 - val_loss: 0.2905 - val_accuracy: 0.9328
# Epoch 31/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.3072 - accuracy: 0.8674 - val_loss: 0.2883 - val_accuracy: 0.9076
# Epoch 32/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.3135 - accuracy: 0.8665 - val_loss: 0.2406 - val_accuracy: 0.9244
# Epoch 33/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2863 - accuracy: 0.8758 - val_loss: 0.2609 - val_accuracy: 0.9412
# Epoch 34/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.2919 - accuracy: 0.8711 - val_loss: 0.2368 - val_accuracy: 0.9328
# Epoch 35/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2832 - accuracy: 0.8805 - val_loss: 0.3280 - val_accuracy: 0.8992
# Epoch 36/100
# 22/22 [==============================] - 1s 37ms/step - loss: 0.2984 - accuracy: 0.8730 - val_loss: 0.1795 - val_accuracy: 0.9328
# Epoch 37/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2784 - accuracy: 0.8777 - val_loss: 0.1898 - val_accuracy: 0.9412
# Epoch 38/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2666 - accuracy: 0.8852 - val_loss: 0.2702 - val_accuracy: 0.8992
# Epoch 39/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.2622 - accuracy: 0.8861 - val_loss: 0.1889 - val_accuracy: 0.9328
# Epoch 40/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.2680 - accuracy: 0.8861 - val_loss: 0.2365 - val_accuracy: 0.9244
# Epoch 41/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2590 - accuracy: 0.8880 - val_loss: 0.2713 - val_accuracy: 0.9328
# Epoch 42/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.2644 - accuracy: 0.8926 - val_loss: 0.2062 - val_accuracy: 0.9496
# Epoch 43/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2767 - accuracy: 0.8842 - val_loss: 0.2836 - val_accuracy: 0.8992
# Epoch 44/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2680 - accuracy: 0.8814 - val_loss: 0.2184 - val_accuracy: 0.9244
# Epoch 45/100
# 22/22 [==============================] - 1s 31ms/step - loss: 0.2617 - accuracy: 0.8861 - val_loss: 0.2260 - val_accuracy: 0.8992
# Epoch 46/100
# 22/22 [==============================] - 1s 32ms/step - loss: 0.2449 - accuracy: 0.8908 - val_loss: 0.2484 - val_accuracy: 0.9076

# %%
# 8. Evaluate the model
test_loss, test_accuracy = lstm_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1795 - accuracy: 0.9328
# Test Loss: 0.1795
# Test Accuracy: 0.9328

# %%
# Make predictions
y_pred = lstm_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 4/4 [==============================] - 2s 10ms/step
# Confusion Matrix:
# [[43  4]
#  [ 4 68]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        47
#            1       0.94      0.94      0.94        72
#
#     accuracy                           0.93       119
#    macro avg       0.93      0.93      0.93       119
# weighted avg       0.93      0.93      0.93       119

# %%
# 4. Hyperparameter tuning
learning_rate = 0.001
batch_size = 50
epochs = 100



# 5. Learning rate scheduling
lr_scheduler = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=learning_rate, decay_steps=10000, decay_rate=0.9
)
optimizer = keras.optimizers.Adam(learning_rate=lr_scheduler)



# 6. Regularization techniques
callback_early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, restore_best_weights=True
)
callback_checkpoint = keras.callbacks.ModelCheckpoint(
    'model_checkpoint.h5', save_best_only=True
)

# %%
def build_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(11, return_sequences=True, input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(GRU(32, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(GRU(64, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(GRU(128, return_sequences=True))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(GRU(128))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(128, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(64, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))  # Output layer
    
    # Compile the model
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# %%
gru_model = build_gru_model(input_shape)
gru_model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test),
             callbacks=[callback_early_stopping, callback_checkpoint])
# Out:
# Epoch 1/100
# 22/22 [==============================] - 20s 204ms/step - loss: 0.6467 - accuracy: 0.6667 - val_loss: 0.6828 - val_accuracy: 0.6050
# Epoch 2/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.5250 - accuracy: 0.7432 - val_loss: 0.6828 - val_accuracy: 0.6050
# Epoch 3/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.4884 - accuracy: 0.7806 - val_loss: 0.6774 - val_accuracy: 0.6050
# Epoch 4/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.4466 - accuracy: 0.7955 - val_loss: 0.6580 - val_accuracy: 0.7815
# Epoch 5/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.4338 - accuracy: 0.8105 - val_loss: 0.6503 - val_accuracy: 0.6891
# Epoch 6/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.4224 - accuracy: 0.8002 - val_loss: 0.6500 - val_accuracy: 0.6723
# Epoch 7/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.4332 - accuracy: 0.8161 - val_loss: 0.6315 - val_accuracy: 0.6471
# Epoch 8/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.4302 - accuracy: 0.8123 - val_loss: 0.6437 - val_accuracy: 0.7983
# Epoch 9/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.3925 - accuracy: 0.8217 - val_loss: 0.6308 - val_accuracy: 0.7143
# Epoch 10/100
# 22/22 [==============================] - 2s 70ms/step - loss: 0.4114 - accuracy: 0.8142 - val_loss: 0.5344 - val_accuracy: 0.8571
# Epoch 11/100
# 22/22 [==============================] - 2s 70ms/step - loss: 0.3899 - accuracy: 0.8366 - val_loss: 0.4720 - val_accuracy: 0.8571
# Epoch 12/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.4151 - accuracy: 0.8179 - val_loss: 0.4603 - val_accuracy: 0.8151
# Epoch 13/100
# 22/22 [==============================] - 2s 71ms/step - loss: 0.4023 - accuracy: 0.8133 - val_loss: 0.4211 - val_accuracy: 0.8824
# Epoch 14/100
# 22/22 [==============================] - 2s 70ms/step - loss: 0.3885 - accuracy: 0.8263 - val_loss: 0.3489 - val_accuracy: 0.8992
# Epoch 15/100
# 22/22 [==============================] - 1s 67ms/step - loss: 0.3715 - accuracy: 0.8413 - val_loss: 0.3624 - val_accuracy: 0.8992
# Epoch 16/100
# 22/22 [==============================] - 2s 75ms/step - loss: 0.3661 - accuracy: 0.8422 - val_loss: 0.3314 - val_accuracy: 0.9076
# Epoch 17/100
# 22/22 [==============================] - 2s 73ms/step - loss: 0.3648 - accuracy: 0.8319 - val_loss: 0.2869 - val_accuracy: 0.9160
# Epoch 18/100
# 22/22 [==============================] - 2s 73ms/step - loss: 0.3597 - accuracy: 0.8366 - val_loss: 0.2820 - val_accuracy: 0.8992
# Epoch 19/100
# 22/22 [==============================] - 2s 72ms/step - loss: 0.3421 - accuracy: 0.8497 - val_loss: 0.2551 - val_accuracy: 0.8992
# Epoch 20/100
# 22/22 [==============================] - 2s 72ms/step - loss: 0.3254 - accuracy: 0.8637 - val_loss: 0.2458 - val_accuracy: 0.9160
# Epoch 21/100
# 22/22 [==============================] - 2s 75ms/step - loss: 0.3494 - accuracy: 0.8487 - val_loss: 0.2137 - val_accuracy: 0.9076
# Epoch 22/100
# 22/22 [==============================] - 1s 64ms/step - loss: 0.3321 - accuracy: 0.8497 - val_loss: 0.2195 - val_accuracy: 0.9160
# Epoch 23/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.3554 - accuracy: 0.8543 - val_loss: 0.2438 - val_accuracy: 0.9076
# Epoch 24/100
# 22/22 [==============================] - 2s 72ms/step - loss: 0.3259 - accuracy: 0.8665 - val_loss: 0.1974 - val_accuracy: 0.9244
# Epoch 25/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.3173 - accuracy: 0.8665 - val_loss: 0.2214 - val_accuracy: 0.9076
# Epoch 26/100
# 22/22 [==============================] - 2s 73ms/step - loss: 0.3151 - accuracy: 0.8711 - val_loss: 0.1865 - val_accuracy: 0.9412
# Epoch 27/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.2996 - accuracy: 0.8768 - val_loss: 0.2178 - val_accuracy: 0.9160
# Epoch 28/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.2900 - accuracy: 0.8739 - val_loss: 0.2539 - val_accuracy: 0.9076
# Epoch 29/100
# 22/22 [==============================] - 2s 72ms/step - loss: 0.3074 - accuracy: 0.8683 - val_loss: 0.1766 - val_accuracy: 0.9580
# Epoch 30/100
# 22/22 [==============================] - 1s 64ms/step - loss: 0.2962 - accuracy: 0.8739 - val_loss: 0.2242 - val_accuracy: 0.9160
# Epoch 31/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.3092 - accuracy: 0.8749 - val_loss: 0.2136 - val_accuracy: 0.9328
# Epoch 32/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.2756 - accuracy: 0.8805 - val_loss: 0.2347 - val_accuracy: 0.9412
# Epoch 33/100
# 22/22 [==============================] - 1s 64ms/step - loss: 0.2560 - accuracy: 0.8982 - val_loss: 0.1920 - val_accuracy: 0.9412
# Epoch 34/100
# 22/22 [==============================] - 1s 64ms/step - loss: 0.2729 - accuracy: 0.8796 - val_loss: 0.2395 - val_accuracy: 0.9160
# Epoch 35/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.2701 - accuracy: 0.8870 - val_loss: 0.2214 - val_accuracy: 0.9412
# Epoch 36/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.2449 - accuracy: 0.8973 - val_loss: 0.1909 - val_accuracy: 0.9412
# Epoch 37/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.2208 - accuracy: 0.9104 - val_loss: 0.2324 - val_accuracy: 0.9328
# Epoch 38/100
# 22/22 [==============================] - 1s 63ms/step - loss: 0.2469 - accuracy: 0.9029 - val_loss: 0.2411 - val_accuracy: 0.9244
# Epoch 39/100
# 22/22 [==============================] - 1s 65ms/step - loss: 0.2267 - accuracy: 0.9066 - val_loss: 0.2125 - val_accuracy: 0.9496

# %%
# 8. Evaluate the model
test_loss, test_accuracy = gru_model.evaluate(X_test, y_test)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1766 - accuracy: 0.9580
# Test Loss: 0.1766
# Test Accuracy: 0.9580

# %%
# Make predictions
y_pred = gru_model.predict(X_test)
y_pred_classes = np.round(y_pred)


# Calculate confusion matrix and classification report
from sklearn.metrics import confusion_matrix, classification_report


conf_matrix = confusion_matrix(y_test, y_pred_classes)
class_report = classification_report(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(class_report)
# Out:
# 4/4 [==============================] - 3s 13ms/step
# Confusion Matrix:
# [[45  2]
#  [ 3 69]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        47
#            1       0.97      0.96      0.97        72
#
#     accuracy                           0.96       119
#    macro avg       0.95      0.96      0.96       119
# weighted avg       0.96      0.96      0.96       119

# %%
# Make predictions using individual models
cnn_predictions = (cnn_model.predict(X_test) > 0.5).astype("int32")
lstm_predictions = (lstm_model.predict(X_test) > 0.5).astype("int32")
gru_predictions = (gru_model.predict(X_test) > 0.5).astype("int32")
# Out:
# 4/4 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 17ms/step

# %%
# Combine predictions using a majority voting ensemble
ensemble_predictions = np.mean([cnn_predictions, lstm_predictions, gru_predictions], axis=0) >= 0.5
ensemble_predictions = ensemble_predictions.astype("int32")

# %%
# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, ensemble_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.9496

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, ensemble_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, ensemble_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, ensemble_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Confusion Matrix:
# [[45  2]
#  [ 4 68]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        47
#            1       0.97      0.94      0.96        72
#
#     accuracy                           0.95       119
#    macro avg       0.94      0.95      0.95       119
# weighted avg       0.95      0.95      0.95       119
#
# Ensemble Accuracy: 0.9496

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.utils import resample
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.model_selection import cross_val_score

# %%
# List of base models

lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

svm_l_model = SVC(kernel="linear")
svm_l_model.fit(X_train, y_train)

svm_p_model = SVC(kernel="poly")
svm_p_model.fit(X_train, y_train)

svm_r_model = SVC(kernel="rbf")
svm_r_model.fit(X_train, y_train)

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)


knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)

gb_model = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_model.fit(X_train, y_train)

ab_model = AdaBoostClassifier(n_estimators=100, random_state=42)
ab_model.fit(X_train, y_train)

xgb_model = XGBClassifier(n_estimators=100, random_state=42)
xgb_model.fit(X_train, y_train)

gpc_model = GaussianProcessClassifier(random_state=42)
gpc_model.fit(X_train, y_train)
# Out:
# GaussianProcessClassifier(random_state=42)

# %%
lr_predictions = lr_model.predict(X_test)
svm_l_predictions = svm_l_model.predict(X_test)
svm_p_predictions = svm_p_model.predict(X_test)
svm_r_predictions = svm_r_model.predict(X_test)
rf_predictions = rf_model.predict(X_test)
knn_predictions = knn_model.predict(X_test)
gb_predictions = gb_model.predict(X_test)
ab_predictions = ab_model.predict(X_test)
xgb_predictions = xgb_model.predict(X_test)
gpc_predictions = gpc_model.predict(X_test)

# %%
# Combine predictions using ensemble (Voting Classifier)
ensemble_predictions = np.column_stack((cnn_predictions, lstm_predictions, gru_predictions, lr_predictions, 
                                        svm_l_predictions, svm_p_predictions, svm_r_predictions, 
                                        rf_predictions, knn_predictions, gb_predictions, 
                                        ab_predictions, xgb_predictions, gpc_predictions))

# %%
# Perform majority voting to get the final prediction
final_predictions = np.mean(ensemble_predictions, axis=1) >= 0.5
final_predictions = final_predictions.astype("int32")

# %%
# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.9412

# %%
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, final_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, final_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Confusion Matrix:
# [[45  2]
#  [ 5 67]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93        47
#            1       0.97      0.93      0.95        72
#
#     accuracy                           0.94       119
#    macro avg       0.94      0.94      0.94       119
# weighted avg       0.94      0.94      0.94       119
#
# Ensemble Accuracy: 0.9412

# %%
# Combine predictions using ensemble (Voting Classifier)
ensemble_predictions = np.column_stack((cnn_predictions, lstm_predictions, gru_predictions, svm_r_predictions, 
                                        rf_predictions, knn_predictions, gb_predictions, 
                                        xgb_predictions, gpc_predictions))

# %%
# Perform majority voting to get the final prediction
final_predictions = np.mean(ensemble_predictions, axis=1) >= 0.5
final_predictions = final_predictions.astype("int32")

# Calculate accuracy of the ensemble
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, final_predictions)

print("Confusion Matrix:")
print(conf_matrix)

# Print classification report
class_report = classification_report(y_test, final_predictions)
print("Classification Report:")
print(class_report)

# Evaluate ensemble accuracy
ensemble_accuracy = accuracy_score(y_test, final_predictions)
print(f"Ensemble Accuracy: {ensemble_accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.9496
# Confusion Matrix:
# [[45  2]
#  [ 4 68]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        47
#            1       0.97      0.94      0.96        72
#
#     accuracy                           0.95       119
#    macro avg       0.94      0.95      0.95       119
# weighted avg       0.95      0.95      0.95       119
#
# Ensemble Accuracy: 0.9496
